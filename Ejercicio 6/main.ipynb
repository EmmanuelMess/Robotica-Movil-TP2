# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import re

# %%
data = pd.read_csv("logcircular.txt", sep="\t", header=None, names=["timestamp", "x", "y", "theta", "v", "w"])

data["nanosecs"] = data.apply(lambda row: re.match("(?:builtin_interfaces\.msg\.Time\(sec=\d+, nanosec=)(\d+)(?:\))", row.timestamp).group(1), axis=1)
data["secs"] = data.apply(lambda row: re.match("(?:builtin_interfaces\.msg\.Time\(sec=)(\d+)(?:, nanosec=\d+\))", row.timestamp).group(1), axis=1)

data["g_timestamp"] = data.apply(lambda row: np.float64(row.secs) + np.float64(row.nanosecs) * 10e-10, axis=1)

data
# Out:
#                                              timestamp         x         y  \
# 0    builtin_interfaces.msg.Time(sec=1694724337, na...  0.171383 -0.565055
# 1    builtin_interfaces.msg.Time(sec=1694724337, na...  0.186742 -0.557903
# 2    builtin_interfaces.msg.Time(sec=1694724338, na...  0.201858 -0.550234
# 3    builtin_interfaces.msg.Time(sec=1694724338, na...  0.216713 -0.542029
# 4    builtin_interfaces.msg.Time(sec=1694724338, na...  0.231238 -0.533388
# ..                                                 ...       ...       ...
# 512  builtin_interfaces.msg.Time(sec=1694724359, na... -0.501934 -0.294298
# 513  builtin_interfaces.msg.Time(sec=1694724359, na... -0.496113 -0.309722
# 514  builtin_interfaces.msg.Time(sec=1694724359, na... -0.489623 -0.325201
# 515  builtin_interfaces.msg.Time(sec=1694724359, na... -0.482550 -0.340576
# 516  builtin_interfaces.msg.Time(sec=1694724359, na... -0.474961 -0.355703
#
#         theta         v         w   nanosecs        secs   g_timestamp
# 0    0.420715  0.485085  0.984772  916671708  1694724337  1.694724e+09
# 1    0.454345  0.475673  0.999336  964254478  1694724337  1.694724e+09
# 2    0.487870  0.510900  0.967641    3848045  1694724338  1.694724e+09
# 3    0.520354  0.534235  0.893789   39411596  1694724338  1.694724e+09
# 4    0.553185  0.529685  0.914155   66254725  1694724338  1.694724e+09
# ..        ...       ...       ...        ...         ...           ...
# 512 -1.227441  0.461074  1.008316  129425161  1694724359  1.694724e+09
# 513 -1.190213  0.431479  1.108468  161302069  1694724359  1.694724e+09
# 514 -1.155497  0.441241  1.035600  196369573  1694724359  1.694724e+09
# 515 -1.121748  0.457499  1.014760  238357137  1694724359  1.694724e+09
# 516 -1.087961  0.436069  1.020414  281020620  1694724359  1.694724e+09
#
# [517 rows x 9 columns]

# %% [markdown]
# ## a)

# %%
plt.rcParams["figure.figsize"] = (5,5)

plt.scatter(data.x, data.y, marker=".", linewidths=0.1)
plt.title("Posiciones del robot")
plt.savefig("a", dpi=600)
plt.show()

plt.rcParams["figure.figsize"] = (6.4, 4.8)

# %%
plt.rcParams["figure.figsize"] = (20,20)

plt.quiver(data.x, data.y, np.cos(data.theta), np.sin(data.theta), color='r', units='xy', scale=100, linewidths=0.1)
plt.quiver(data.x, data.y, -np.sin(data.theta), np.cos(data.theta), color='g', units='xy', scale=100, linewidths=0.1)

plt.title("Pose del robot")
plt.savefig("b", dpi=600)
plt.show()

plt.rcParams["figure.figsize"] = (6.4, 4.8)

plt.plot(data.g_timestamp, data.x)
plt.title("Coordenada X en el tiempo")
plt.show()

plt.plot(data.g_timestamp, data.y)
plt.title("Coordenada Y en el tiempo")
plt.show()

plt.plot(data.g_timestamp, data.theta)
plt.title("Angulo en el tiempo")
plt.show()

# %% [markdown]
# ## c)

# %%
plt.plot(data.g_timestamp, data.v)
plt.title("Velocidad del robot en el tiempo")
plt.savefig("c", dpi=600)
plt.show()
